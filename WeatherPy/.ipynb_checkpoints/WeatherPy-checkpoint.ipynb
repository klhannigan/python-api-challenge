# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 613

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units=metrics"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        weather_response = requests.get(city_url)
        city_weather = weather_response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint-joseph
# Processing Record 2 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 3 of Set 1 | palikir - national government center
# Processing Record 4 of Set 1 | ilulissat
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | ust-nera
# Processing Record 7 of Set 1 | gizo
# Processing Record 8 of Set 1 | taldykorgan
# Processing Record 9 of Set 1 | port mathurin
# Processing Record 10 of Set 1 | port-aux-francais
# Processing Record 11 of Set 1 | kimbe
# Processing Record 12 of Set 1 | kodiak
# Processing Record 13 of Set 1 | iqaluit
# Processing Record 14 of Set 1 | tual
# Processing Record 15 of Set 1 | gulf shores
# Processing Record 16 of Set 1 | margaret river
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | adamstown
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | cavelossim
# Processing Record 22 of Set 1 | barro alto
# Processing Record 23 of Set 1 | ryotsu-minato
# Processing Record 24 of Set 1 | isafjordur
# Processing Record 25 of Set 1 | zmiyevka
# Processing Record 26 of Set 1 | oederan
# Processing Record 27 of Set 1 | nizhniy kuranakh
# Processing Record 28 of Set 1 | bilibino
# Processing Record 29 of Set 1 | ceres
# Processing Record 30 of Set 1 | grytviken
# Processing Record 31 of Set 1 | qaqortoq
# Processing Record 32 of Set 1 | kourou
# Processing Record 33 of Set 1 | lihue
# Processing Record 34 of Set 1 | olonkinbyen
# Processing Record 35 of Set 1 | brisas de zicatela
# Processing Record 36 of Set 1 | puerto colombia
# Processing Record 37 of Set 1 | queenstown
# Processing Record 38 of Set 1 | swift current
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | ta`u
# Processing Record 41 of Set 1 | port lincoln
# Processing Record 42 of Set 1 | ormara
# Processing Record 43 of Set 1 | amungan
# Processing Record 44 of Set 1 | portland
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | udachny
# Processing Record 47 of Set 1 | katsuura
# Processing Record 48 of Set 1 | longyearbyen
# Processing Record 49 of Set 1 | college
# Processing Record 50 of Set 1 | talnakh
# Processing Record 0 of Set 2 | am djarass
# City not found. Skipping...
# Processing Record 1 of Set 2 | san jose village
# City not found. Skipping...
# Processing Record 2 of Set 2 | ponta delgada
# Processing Record 3 of Set 2 | mount gambier
# Processing Record 4 of Set 2 | menaka
# Processing Record 5 of Set 2 | polyarnyy
# Processing Record 6 of Set 2 | solnechnyy
# Processing Record 7 of Set 2 | puerto natales
# Processing Record 8 of Set 2 | puerto real
# Processing Record 9 of Set 2 | atafu village
# Processing Record 10 of Set 2 | vilyuchinsk
# Processing Record 11 of Set 2 | coxen hole
# Processing Record 12 of Set 2 | ciudad melchor muzquiz
# Processing Record 13 of Set 2 | lata
# Processing Record 14 of Set 2 | bonthe
# Processing Record 15 of Set 2 | utrik
# Processing Record 16 of Set 2 | lesnikovo
# Processing Record 17 of Set 2 | jabor
# Processing Record 18 of Set 2 | zykovo
# Processing Record 19 of Set 2 | dryden
# Processing Record 20 of Set 2 | kayangel
# Processing Record 21 of Set 2 | waitangi
# Processing Record 22 of Set 2 | melekeok village
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | afaahiti
# Processing Record 25 of Set 2 | susuman
# Processing Record 26 of Set 2 | ancud
# Processing Record 27 of Set 2 | papatowai
# Processing Record 28 of Set 2 | tiksi
# Processing Record 29 of Set 2 | fort bragg
# Processing Record 30 of Set 2 | hasaki
# Processing Record 31 of Set 2 | masterton
# Processing Record 32 of Set 2 | togur
# Processing Record 33 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record
of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 4 of Set 4 | edinburgh of the seven seas
# Processing Record 5 of Set 4 | constantia
# Processing Record 6 of Set 4 | bcharre
# Processing Record 7 of Set 4 | kawthoung
# City not found. Skipping...
# Processing Record 8 of Set 4 | tazacorte
# Processing Record 9 of Set 4 | yuzhno-kurilsk
# Processing Record 10 of Set 4 | aasiaat
# Processing Record 11 of Set 4 | santa cruz
# Processing Record 12 of Set 4 | parkes
# Processing Record 13 of Set 4 | kargil
# Processing Record 14 of Set 4 | key west
# Processing Record 15 of Set 4 | vernon
# Processing Record 16 of Set 4 | ketchikan
# Processing Record 17 of Set 4 | fort mcmurray
# Processing Record 18 of Set 4 | keflavik
# Processing Record 19 of Set 4 | lisala
# Processing Record 20 of Set 4 | ilha de mocambique
# Processing Record 21 of Set 4 | haiku-pauwela
# Processing Record 22 of Set 4 | jagatsinghapur
# Processing Record 23 of Set 4 | punta arenas
# Processing Record 24 of Set 4 | sogndal
# Processing Record 25 of Set 4 | vorgashor
# Processing Record 26 of Set 4 | east london
# Processing Record 27 of Set 4 | xiongzhou
# Processing Record 28 of Set 4 | fidenza
# Processing Record 29 of Set 4 | sakakah
# Processing Record 30 of Set 4 | guarapari
# Processing Record 31 of Set 4 | mata-utu
# Processing Record 32 of Set 4 | stutterheim
# Processing Record 33 of Set 4 | hawaiian paradise park
# Processing Record 34 of Set 4 | seaside
# Processing Record 35 of Set 4 | puerto baquerizo moreno
# Processing Record 36 of Set 4 | ad-damazin
# Processing Record 37 of Set 4 | broken hill
# Processing Record 38 of Set 4 | kavaratti
# Processing Record 39 of Set 4 | mweka
# Processing Record 40 of Set 4 | stanley
# Processing Record 41 of Set 4 | maridi
# Processing Record 42 of Set 4 | solleftea
# Processing Record 43 of Set 4 | thompson
# Processing Record 44 of Set 4 | las tablas
# Processing Record 45 of Set 4 | kone
# Processing Record 46 of Set 4 | la sarre
# Processing Record 47 of Set 4 | san jose de guanipa
# Processing Record 48 of Set 4 | mato verde
# Processing Record 49 of Set 4 | hassi messaoud
# Processing Record 0 of Set 5 | klyuchi
# Processing Record 1 of Set 5 | margate
# Processing Record 2 of Set 5 | tekeli
# Processing Record 3 of Set 5 | guankou
# Processing Record 4 of Set 5 | dan sadau
# Processing Record 5 of Set 5 | soe
# Processing Record 6 of Set 5 | sitka
# Processing Record 7 of Set 5 | ouadda
# Processing Record 8 of Set 5 | anna regina
# Processing Record 9 of Set 5 | novo brdo
# Processing Record 10 of Set 5 | laela
# Processing Record 11 of Set 5 | timbuktu
# Processing Record 12 of Set 5 | lorengau
# Processing Record 13 of Set 5 | geraldton
# Processing Record 14 of Set 5 | bodaybo
# Processing Record 15 of Set 5 | lompoc
# Processing Record 16 of Set 5 | luanco
# Processing Record 17 of Set 5 | la passe
# Processing Record 18 of Set 5 | puerto deseado
# Processing Record 19 of Set 5 | charters towers
# Processing Record 20 of Set 5 | saint-philippe
# Processing Record 21 of Set 5 | novoishimskiy
# Processing Record 22 of Set 5 | g'uzor
# Processing Record 23 of Set 5 | vila franca do campo
# Processing Record 24 of Set 5 | howrah
# Processing Record 25 of Set 5 | dunedin
# Processing Record 26 of Set 5 | san antonio de pale
# Processing Record 27 of Set 5 | invercargill
# Processing Record 28 of Set 5 | badger
# Processing Record 29 of Set 5 | darwin
# Processing Record 30 of Set 5 | ulsteinvik
# Processing Record 31 of Set 5 | singaraja
# Processing Record 32 of Set 5 | kiruna
# Processing Record 33 of Set 5 | ambodifotatra
# Processing Record 34 of Set 5 | richlands
# Processing Record 35 of Set 5 | chernyshevskiy
# Processing Record 36 of Set 5 | pyapon
# Processing Record 37 of Set 5 | lebu
# Processing Record 38 of Set 5 | dudinka
# Processing Record 39 of Set 5 | crane
# Processing Record 40 of Set 5 | fortuna foothills
# Processing Record 41 of Set 5 | labytnangi
# Processing Record 42 of Set 5 | florencia
# Processing Record 43 of Set 5 | gadzhiyevo
# Processing Record 44 of Set 5 | hirara
# Processing Record 45 of Set 5 | georgetown
# Processing Record 46 of Set 5 | puerto armuelles
# Processing Record 47 of Set 5 | niquelandia
# Processing Record 48 of Set 5 | botticino
# Processing Record 49 of Set 5 | banda aceh
# Processing Record 0 of Set 6 | ambon
# Processing Record 1 of Set 6 | chinchilla
# Processing Record 2 of Set 6 | vanino
# Processing Record 3 of Set 6 | uturoa
# Processing Record 4 of Set 6 | fulton
# Processing Record 5 of Set 6 | whangarei
# Processing Record 6 of Set 6 | shushtar
# Processing Record 7 of Set 6 | springbok
# Processing Record 8 of Set 6 | abu road
# Processing Record 9 of Set 6 | nar'yan-mar
# Processing Record 10 of Set 6 | salinopolis
# Processing Record 11 of Set 6 | waycross
# Processing Record 12 of Set 6 | gwadar
# Processing Record 13 of Set 6 | sultanah
# Processing Record 14 of Set 6 | sao felix do xingu
# Processing Record 15 of Set 6 | cabanglasan
# Processing Record 16 of Set 6 | sarmiento
# Processing Record 17 of Set 6 | remire-montjoly
# Processing Record 18 of Set 6 | whitehorse
# Processing Record 19 of Set 6 | hamilton
# Processing Record 20 of Set 6 | kiiminki
# Processing Record 21 of Set 6 | khonsa
# Processing Record 22 of Set 6 | luganville
# Processing Record 23 of Set 6 | carnarvon
# Processing Record 24 of Set 6 | rio san juan
# Processing Record 25 of Set 6 | tsiombe
# Processing Record 26 of Set 6 | westport
# Processing Record 27 of Set 6 | boromo
# Processing Record 28 of Set 6 | kokofata
# City not found. Skipping...
# Processing Record 29 of Set 6 | savanna-la-mar
# Processing Record 30 of Set 6 | champerico
# Processing Record 31 of Set 6 | natal
# Processing Record 32 of Set 6 | dawson creek
# Processing Record 33 of Set 6 | usinsk
# Processing Record 34 of Set 6 | isfahan
# Processing Record 35 of Set 6 | la cumbre
# Processing Record 36 of Set 6 | bria
# Processing Record 37 of Set 6 | canmore
# Processing Record 29 of Set 9 | mentekab
# Processing Record 30 of Set 9 | narasannapeta
# Processing Record 31 of Set 9 | singkil
# Processing Record 32 of Set 9 | spring creek
# Processing Record 33 of Set 9 | taroa
# Processing Record 34 of Set 9 | castro
# Processing Record 35 of Set 9 | chimore
# Processing Record 36 of Set 9 | minas de marcona
# Processing Record 37 of Set 9 | kununurra
# Processing Record 38 of Set 9 | saynshand
# Processing Record 39 of Set 9 | tarko-sale
# Processing Record 40 of Set 9 | malvan
# Processing Record 41 of Set 9 | beboto
# Processing Record 42 of Set 9 | rio branco
# Processing Record 43 of Set 9 | wanning
# Processing Record 44 of Set 9 | ipatovo
# Processing Record 45 of Set 9 | al kharijah
# Processing Record 46 of Set 9 | dampit
# Processing Record 47 of Set 9 | grand falls-windsor
# Processing Record 48 of Set 9 | nerchinsk
# Processing Record 49 of Set 9 | arroyo
# Processing Record 0 of Set 10 | cargados carajos
# City not found. Skipping...
# Processing Record 1 of Set 10 | parral
# Processing Record 2 of Set 10 | brooks
# Processing Record 3 of Set 10 | tamandare
# Processing Record 4 of Set 10 | alo
# Processing Record 5 of Set 10 | dalbandin
# Processing Record 6 of Set 10 | jurm
# Processing Record 7 of Set 10 | mount isa
# Processing Record 8 of Set 10 | callao
# Processing Record 9 of Set 10 | hancheng
# Processing Record 10 of Set 10 | yigo village
# Processing Record 11 of Set 10 | sydney
# Processing Record 12 of Set 10 | plettenberg bay
# Processing Record 13 of Set 10 | aberdeen
# Processing Record 14 of Set 10 | rakops
# Processing Record 15 of Set 10 | puerto san carlos
# City not found. Skipping...
# Processing Record 16 of Set 10 | port isabel
# Processing Record 17 of Set 10 | machico
# Processing Record 18 of Set 10 | crucecita
# Processing Record 19 of Set 10 | antonio enes
# Processing Record 20 of Set 10 | thurso
# Processing Record 21 of Set 10 | sangmelima
# Processing Record 22 of Set 10 | olovyannaya
# Processing Record 23 of Set 10 | byron bay
# Processing Record 24 of Set 10 | vertientes
# Processing Record 25 of Set 10 | port douglas
# Processing Record 26 of Set 10 | imperatriz
# Processing Record 27 of Set 10 | mozarlandia
# Processing Record 28 of Set 10 | nabire
# Processing Record 29 of Set 10 | urcos
# Processing Record 30 of Set 10 | prince rupert
# Processing Record 31 of Set 10 | flying fish cove
# Processing Record 32 of Set 10 | ayaguz
# City not found. Skipping...
# Processing Record 33 of Set 10 | horta
# Processing Record 34 of Set 10 | broome
# Processing Record 35 of Set 10 | ploneour-lanvern
# Processing Record 36 of Set 10 | tazovsky
# Processing Record 37 of Set 10 | ghanzi
# Processing Record 38 of Set 10 | radyvyliv
# Processing Record 39 of Set 10 | burley
# Processing Record 40 of Set 10 | giado
# Processing Record 41 of Set 10 | muzaffarabad
# Processing Record 42 of Set 10 | saudarkrokur
# Processing Record 43 of Set 10 | halifax
# Processing Record 44 of Set 10 | blatna
# Processing Record 45 of Set 10 | serenje
# Processing Record 46 of Set 10 | sumbe
# Processing Record 47 of Set 10 | carutapera
# Processing Record 48 of Set 10 | rio turbio
# City not found. Skipping...
# Processing Record 49 of Set 10 | brookings
# Processing Record 0 of Set 11 | bardai
# Processing Record 1 of Set 11 | anan
# Processing Record 2 of Set 11 | salahonda
# Processing Record 3 of Set 11 | nadi
# Processing Record 4 of Set 11 | sao vicente
# Processing Record 5 of Set 11 | ashtarak
# Processing Record 6 of Set 11 | praia da vitoria
# Processing Record 7 of Set 11 | berezovyy
# Processing Record 8 of Set 11 | north bend
# Processing Record 9 of Set 11 | assab
# Processing Record 10 of Set 11 | kittila
# Processing Record 11 of Set 11 | hermosillo
# Processing Record 12 of Set 11 | nanded
# City not found. Skipping...
# Processing Record 13 of Set 11 | horad zhodzina
# Processing Record 14 of Set 11 | iskateley
# Processing Record 15 of Set 11 | fisterra
# Processing Record 16 of Set 11 | toliara
# Processing Record 17 of Set 11 | ghadamis
# Processing Record 18 of Set 11 | shalqar
# Processing Record 19 of Set 11 | barcelos
# Processing Record 20 of Set 11 | gwanda
# Processing Record 21 of Set 11 | ebon
# Processing Record 22 of Set 11 | dergachi
# Processing Record 23 of Set 11 | khorinsk
# Processing Record 24 of Set 11 | island harbour
# Processing Record 25 of Set 11 | kerikeri
# Processing Record 26 of Set 11 | hollister
# Processing Record 27 of Set 11 | rochester
# Processing Record 28 of Set 11 | villa gesell
# Processing Record 29 of Set 11 | guerrero negro
# Processing Record 30 of Set 11 | bata
# Processing Record 31 of Set 11 | sampit
# Processing Record 32 of Set 11 | sharan
# Processing Record 33 of Set 11 | as sanad
# Processing Record 34 of Set 11 | pailin
# Processing Record 35 of Set 11 | nouadhibou
# Processing Record 36 of Set 11 | santana
# Processing Record 37 of Set 11 | balikpapan
# Processing Record 38 of Set 11 | warwick
# Processing Record 39 of Set 11 | berdigestyakh
# Processing Record 40 of Set 11 | weno
# Processing Record 41 of Set 11 | bom jesus
# Processing Record 42 of Set 11 | whakatane
# Processing Record 43 of Set 11 | shanhaiguan
# Processing Record 44 of Set 11 | ghat
# Processing Record 45 of Set 11 | cadale
# Processing Record 46 of Set 11 | rudnichnyy
# Processing Record 47 of Set 11 | barra
# Processing Record 48 of Set 11 | svidnik
# Processing Record 49 of Set 11 | lae
# Processing Record 0 of Set 12 | suntar
# Processing Record 1 of Set 12 | jiuquan
# Processing Record 2 of Set 12 | kapuskasing
# Processing Record 3 of Set 12 | tromso
# Processing Record 4 of Set 12 | kawalu
# Processing Record 5 of Set 12 | knysna
# Processing Record 6 of Set 12 | nova sintra
# Processing Record 7 of Set 12 | san patricio
# Processing Record 8 of Set 12 | le port
# Processing Record 9 of Set 12 | ust-tsilma
# Processing Record 10 of Set 12 | itatiaia
# Processing Record 11 of Set 12 | zyrya
# Processing Record 12 of Set 12 | hithadhoo
# Processing Record 13 of Set 12 | mermoz boabab
# Processing Record 14 of Set 12 | lucapa
# Processing Record 15 of Set 12 | smithers
# Processing Record 16 of Set 12 | palora
# Processing Record 17 of Set 12 | port glaud
# City not found. Skipping...
# Processing Record 18 of Set 12 | pisco
# Processing Record 19 of Set 12 | new plymouth
# Processing Record 20 of Set 12 | kemijarvi
# Processing Record 21 of Set 12 | puerto carreno
# Processing Record 22 of Set 12 | montepuez
# Processing Record 23 of Set 12 | yatou
# Processing Record 24 of Set 12 | vorkuta
# Processing Record 25 of Set 12 | santa elena de uairen
# Processing Record 26 of Set 12 | marsh harbour
# Processing Record 27 of Set 12 | trairi
# Processing Record 28 of Set 12 | sechura
# Processing Record 29 of Set 12 | gobabis
# Processing Record 30 of Set 12 | kushiro
# Processing Record 31 of Set 12 | labrador city
# Processing Record 32 of Set 12 | huittinen
# Processing Record 33 of Set 12 | ulladulla
# Processing Record 34 of Set 12 | geneina
# Processing Record 35 of Set 12 | casino
# Processing Record 36 of Set 12 | lagoa
# Processing Record 37 of Set 12 | mirriah
# Processing Record 38 of Set 12 | bambui
# Processing Record 39 of Set 12 | nishinoomote
# Processing Record 40 of Set 12 | kingston
# Processing Record 41 of Set 12 | amursk
# Processing Record 42 of Set 12 | mao
# Processing Record 43 of Set 12 | verkhnevilyuysk
# Processing Record 44 of Set 12 | yelan'-koleno
# Processing Record 45 of Set 12 | shakiso
# Processing Record 46 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 47 of Set 12 | santo antonio do ica
# Processing Record 48 of Set 12 | karkira
# Processing Record 49 of Set 12 | sunbury
# Processing Record 0 of Set 13 | pyu
# Processing Record 1 of Set 13 | buritis
# Processing Record 2 of Set 13 | saratamata
# City not found. Skipping...
# Processing Record 3 of Set 13 | burang
# Processing Record 4 of Set 13 | beypore
# Processing Record 5 of Set 13 | amory
# Processing Record 6 of Set 13 | trebon
# Processing Record 7 of Set 13 | ust'-kulom
# Processing Record 8 of Set 13 | nova xavantina
# Processing Record 9 of Set 13 | uige
# Processing Record 10 of Set 13 | kalmunai
# Processing Record 11 of Set 13 | agua dulce
# Processing Record 12 of Set 13 | kataragama
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame.from_dict(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          587
# Lat           587
# Lng           587
# Max Temp      587
# Humidity      587
# Cloudiness    587
# Wind Speed    587
# Country       587
# Date          587
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                                    City      Lat       Lng  Max Temp  \
# 0                          saint-joseph -21.3667   55.6167    297.86
# 1  palikir - national government center   6.9248  158.1611    298.56
# 2                             ilulissat  69.2167  -51.1000    267.16
# 3                             jamestown  42.0970  -79.2353    282.92
# 4                              ust-nera  64.5667  143.2000    241.11
#
#    Humidity  Cloudiness  Wind Speed Country        Date
# 0        82          44        0.63      RE  1699653015
# 1        89         100        0.00      FM  1699653015
# 2        53         100        8.75      GL  1699653016
# 3        62          75        7.20      US  1699652728
# 4        97          55        1.34      RU  1699653016

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                          City      Lat       Lng  Max Temp  \
# City_ID
# 0                                saint-joseph -21.3667   55.6167    297.86
# 1        palikir - national government center   6.9248  158.1611    298.56
# 2                                   ilulissat  69.2167  -51.1000    267.16
# 3                                   jamestown  42.0970  -79.2353    282.92
# 4                                    ust-nera  64.5667  143.2000    241.11
#
#          Humidity  Cloudiness  Wind Speed Country        Date
# City_ID
# 0              82          44        0.63      RE  1699653015
# 1              89         100        0.00      FM  1699653015
# 2              53         100        8.75      GL  1699653016
# 3              62          75        7.20      US  1699652728
# 4              97          55        1.34      RU  1699653016

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], alpha = 0.7, edgecolors = "black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Max Latitude vs Temperature")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], alpha = 0.7, edgecolors = "black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Max Latitude vs Humidity")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], alpha = 0.7, edgecolors = "black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Max Latitude vs Cloudiness")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], alpha = 0.7, edgecolors = "black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Max Latitude vs Wind Speed")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
#(slope, intercept, r_value, p_value, stderr) = linregress(x_values, y_values)
#regress = x_values * slope + intercept
#line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
n_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) >= 0, :]

# Display sample data
n_hemi_df.head()
# Out:
#                                          City      Lat       Lng  Max Temp  \
# City_ID
# 1        palikir - national government center   6.9248  158.1611    298.56
# 2                                   ilulissat  69.2167  -51.1000    267.16
# 3                                   jamestown  42.0970  -79.2353    282.92
# 4                                    ust-nera  64.5667  143.2000    241.11
# 6                                 taldykorgan  45.0156   78.3739    277.73
#
#          Humidity  Cloudiness  Wind Speed Country        Date
# City_ID
# 1              89         100        0.00      FM  1699653015
# 2              53         100        8.75      GL  1699653016
# 3              62          75        7.20      US  1699652728
# 4              97          55        1.34      RU  1699653016
# 6              81           6        2.02      KZ  1699653016

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
s_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) < 0, :]

# Display sample data
s_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             saint-joseph -21.3667   55.6167    297.86        82          44
# 5                     gizo  -8.1030  156.8419    300.85        79         100
# 7            port mathurin -19.6833   63.4167    297.95        79           9
# 8        port-aux-francais -49.3500   70.2167    280.06        96         100
# 9                    kimbe  -5.5502  150.1429    301.31        71          80
#
#          Wind Speed Country        Date
# City_ID
# 0              0.63      RE  1699653015
# 5              8.84      SB  1699653016
# 7              4.91      MU  1699653016
# 8             14.67      TF  1699653017
# 9              2.87      PG  1699653017

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_value = n_hemi_df["Lat"]
y_value = n_hemi_df["Max Temp"]
slope = linregress(x_value, y_value)

(slope, intercept, r_value, p_value, stderr) = linregress(x_value, y_value)
regress = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_value, y_value)
plt.plot(x_value, regress, "-r")
plt.annotate(line_eq, (0, -20), fontsize = 15, color = "red")
plt.xlabel = "Latitude"
plt.ylabel = "Max Temp"
print(f"The r-value is: {r_value}")
# Out:
# The r-value is: -0.845805483284775

# %%
# Linear regression on Southern Hemisphere
x_value = s_hemi_df["Lat"]
y_value = s_hemi_df["Max Temp"]
slope = linregress(x_value, y_value)

(slope, intercept, r_value, p_value, stderr) = linregress(x_value, y_value)
regress = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_value, y_value)
plt.plot(x_value, regress, "-r")
plt.annotate(line_eq, (0, -20), fontsize = 15, color = "red")
plt.xlabel = "Latitude"
plt.ylabel = "Max Temp"
print(f"The r-value is: {r_value}")
# Out:
# The r-value is: 0.6795431461997411

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern hemisphere, as the latitude increases, max temperature decrases.In the Southern hemisphere, as the latitude increases, the max temperature increases as we move closer to the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = n_hemi_df["Lat"]
y_value = n_hemi_df["Humidity"]
slope = linregress(x_value, y_value)

(slope, intercept, r_value, p_value, stderr) = linregress(x_value, y_value)
regress = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_value, y_value)
plt.plot(x_value, regress, "-r")
plt.annotate(line_eq, (0, -20), fontsize = 15, color = "red")
plt.xlabel = "Latitude"
plt.ylabel = "Max Temp"
print(f"The r-value is: {r_value}")
# Out:
# The r-value is: 0.18487960066452053

# %%
# Southern Hemisphere
x_value = s_hemi_df["Lat"]
y_value = s_hemi_df["Humidity"]
slope = linregress(x_value, y_value)

(slope, intercept, r_value, p_value, stderr) = linregress(x_value, y_value)
regress = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_value, y_value)
plt.plot(x_value, regress, "-r")
plt.annotate(line_eq, (0, -20), fontsize = 15, color = "red")
plt.xlabel = "Latitude"
plt.ylabel = "Max Temp"
print(f"The r-value is: {r_value}")
# Out:
# The r-value is: 0.17808978712658297

# %% [markdown]
# **Discussion about the linear relationship:** Slight positive results on both graphs, seems like there isn't a strong coorelation between latitude and humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = n_hemi_df["Lat"]
y_value = n_hemi_df["Cloudiness"]
slope = linregress(x_value, y_value)

(slope, intercept, r_value, p_value, stderr) = linregress(x_value, y_value)
regress = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_value, y_value)
plt.plot(x_value, regress, "-r")
plt.annotate(line_eq, (0, -20), fontsize = 15, color = "red")
plt.xlabel = "Latitude"
plt.ylabel = "Max Temp"
print(f"The r-value is: {r_value}")
# Out:
# The r-value is: 0.039854648250493854

# %%
# Southern Hemisphere
x_value = s_hemi_df["Lat"]
y_value = s_hemi_df["Cloudiness"]
slope = linregress(x_value, y_value)

(slope, intercept, r_value, p_value, stderr) = linregress(x_value, y_value)
regress = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_value, y_value)
plt.plot(x_value, regress, "-r")
plt.annotate(line_eq, (0, -20), fontsize = 15, color = "red")
plt.xlabel = "Latitude"
plt.ylabel = "Max Temp"
print(f"The r-value is: {r_value}")
# Out:
# The r-value is: 0.08213977652056076

# %% [markdown]
# **Discussion about the linear relationship:** Very slight positive results on both graphs, seems like there isn't a strong coorelation between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = n_hemi_df["Lat"]
y_value = n_hemi_df["Wind Speed"]
slope = linregress(x_value, y_value)

(slope, intercept, r_value, p_value, stderr) = linregress(x_value, y_value)
regress = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_value, y_value)
plt.plot(x_value, regress, "-r")
plt.annotate(line_eq, (0, -20), fontsize = 15, color = "red")
plt.xlabel = "Latitude"
plt.ylabel = "Max Temp"
print(f"The r-value is: {r_value}")
# Out:
# The r-value is: 0.0936894137053931

# %%
# Southern Hemisphere
x_value = s_hemi_df["Lat"]
y_value = s_hemi_df["Wind Speed"]
slope = linregress(x_value, y_value)

(slope, intercept, r_value, p_value, stderr) = linregress(x_value, y_value)
regress = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_value, y_value)
plt.plot(x_value, regress, "-r")
plt.annotate(line_eq, (0, -20), fontsize = 15, color = "red")
plt.xlabel = "Latitude"
plt.ylabel = "Max Temp"
print(f"The r-value is: {r_value}")
# Out:
# The r-value is: -0.2500583600316222

# %% [markdown]
# **Discussion about the linear relationship:** It seems like there isn't a strong coorelation between latitude and wind speed.
